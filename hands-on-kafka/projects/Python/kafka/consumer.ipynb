# %%
#!pip install FastAPI

# %%
from kafka import KafkaConsumer
consumer = KafkaConsumer(
    'names',
    bootstrap_servers=['13.90.197.178:9092'],
    group_id='names-consumer-group'
)

for message in consumer:
    print(message)
# Out:
# ConsumerRecord(topic='names', partition=0, offset=400, timestamp=1708166012319, timestamp_type=0, key=None, value=b'Victoria Carpenter', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=18, serialized_header_size=-1)
# ConsumerRecord(topic='names', partition=0, offset=401, timestamp=1708166012320, timestamp_type=0, key=None, value=b'Jacqueline Peterson', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=19, serialized_header_size=-1)
# ConsumerRecord(topic='names', partition=0, offset=402, timestamp=1708166012320, timestamp_type=0, key=None, value=b'John Travis', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=11, serialized_header_size=-1)
# ConsumerRecord(topic='names', partition=0, offset=403, timestamp=1708166012321, timestamp_type=0, key=None, value=b'Jacqueline Ray', headers=[], checksum=None, serialized_key_size=-1, serialized_value_size=14, serialized_header_size=-1)
# ...
